# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv', encoding="ISO-8859-1")

# %%
df_test = pd.read_csv('test.csv', encoding="ISO-8859-1")

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer('english')

# %%
# %%time
df_pro_desc = pd.read_csv('product_descriptions.csv')

num_train = df_train.shape[0]

def str_stemmer(s):
    return " ".join([stemmer.stem(word) for word in s.lower().split()])

def str_common_word(str1, str2):
    return sum(int(str2.find(word)>=0) for word in str1.split())


df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')

df_all['search_term'] = df_all['search_term'].map(lambda x:str_stemmer(x))
df_all['product_title'] = df_all['product_title'].map(lambda x:str_stemmer(x))
df_all['product_description'] = df_all['product_description'].map(lambda x:str_stemmer(x))
# Out:
# CPU times: user 11min 46s, sys: 13.1 s, total: 11min 59s
# Wall time: 13min 16s

# %%
df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)

df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title']+"\t"+df_all['product_description']

df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))

# %%
df_attr = pd.read_csv('attributes.csv')
df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]].rename(columns={"value": "brand"})

# %%
df_all = pd.merge(df_all, df_brand, how='left', on='product_uid')

# %%
df_all['brand'] = df_all['brand'].fillna('unbranded')

# %%
# %%time
df_all['brand'] = df_all['brand'].map(lambda x:str_stemmer(x))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-42-172ec18dbcda> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"df_all['brand'] = df_all['brand'].map(lambda x:str_stemmer(x))")
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2262             magic_arg_s = self.var_expand(line, stack_depth)
#    2263             with self.builtin_trap:
# -> 2264                 result = fn(magic_arg_s, cell)
#    2265             return result
#    2266
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1164         else:
#    1165             st = clock2()
# -> 1166             exec(code, glob, local_ns)
#    1167             end = clock2()
#    1168             out = None
#
# <timed exec> in <module>()
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in map(self, arg, na_action)
#    2014                                      index=self.index).__finalize__(self)
#    2015         else:
# -> 2016             mapped = map_f(values, arg)
#    2017             return self._constructor(mapped,
#    2018                                      index=self.index).__finalize__(self)
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:58435)()
#
# <timed exec> in <lambda>(x)
#
# <timed exec> in str_stemmer(s)
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/nltk/stem/snowball.pyc in stem(self, word)
#     690
#     691         # Map the different apostrophe characters to a single consistent one
# --> 692         word = (word.replace("\u2019", "\x27")
#     693                     .replace("\u2018", "\x27")
#     694                     .replace("\u201B", "\x27"))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 8: ordinal not in range(128)

# %%
df_all['len_of_title'] = df_all['product_title'].map(lambda x:len(x.split())).astype(np.int64)
df_all['len_of_description'] = df_all['product_description'].map(lambda x:len(x.split())).astype(np.int64)
df_all['len_of_brand'] = df_all['brand'].map(lambda x:len(x.split())).astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-833185994106> in <module>()
#       1 df_all['len_of_title'] = df_all['product_title'].map(lambda x:len(x.split())).astype(np.int64)
#       2 df_all['len_of_description'] = df_all['product_description'].map(lambda x:len(x.split())).astype(np.int64)
# ----> 3 df_all['len_of_brand'] = df_all['brand'].map(lambda x:len(x.split())).astype(np.int64)
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/cloudera/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'brand'

# %%
def jackard_similarity_index(x, y):
    x = set(x)
    y = set(y)
    z = x.intersection(y)
    return len(z)/float(len(x)+len(y)-len(z))

# %%
x = df_all['search_term'][0]
y = df_all['product_title'][0]

# %%
# %%time
df_all['jackard_similarity'] = df_all.apply(lambda x: jackard_similarity_index(x['search_term'], x['product_title']), axis=1)
# Out:
# CPU times: user 6.75 s, sys: 194 ms, total: 6.94 s
# Wall time: 7.43 s

# %%
# %%time
df_new = df_all.drop(['search_term','product_title','product_description','product_info'],axis=1)
# Out:
# CPU times: user 3 ms, sys: 15 ms, total: 18 ms
# Wall time: 33.4 ms

# %%
# %%time
df_train = df_new.iloc[:num_train]
df_test = df_new.iloc[num_train:]
id_test = df_test['id']

y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values
# Out:
# CPU times: user 20 ms, sys: 14 ms, total: 34 ms
# Wall time: 42.4 ms

# %%
df_train
# Out:
#            id  product_uid  relevance  len_of_query  word_in_title  \
# 0           2       100001       3.00             2              1
# 1           3       100001       2.50             2              1
# 2           9       100002       3.00             2              1
# 3          16       100005       2.33             3              1
# 4          17       100005       2.67             3              3
# 5          18       100006       3.00             2              1
# 6          20       100006       2.67             3              2
# 7          21       100006       3.00             1              1
# 8          23       100007       2.67             2              2
# 9          27       100009       3.00             2              2
# 10         34       100010       2.67             2              1
# 11         35       100011       3.00             5              4
# 12         37       100011       3.00             2              2
# 13         38       100011       2.00             2              1
# 14         48       100012       2.67             6              4
# 15         51       100013       2.67             1              1
# 16         65       100016       3.00             2              2
# 17         69       100017       1.00             2              0
# 18         75       100017       1.67             4              0
# 19         81       100017       2.33             2              0
# 20         85       100017       2.33             2              0
# 21         88       100019       1.33             4              0
# 22         90       100019       2.67             3              1
# 23         92       100019       2.33             2              1
# 24        101       100019       1.33             2              1
# 25        105       100019       2.33             3              1
# 26        106       100019       2.33             3              2
# 27        113       100021       2.00             2              0
# 28        114       100021       2.33             2              0
# 29        117       100022       2.67             3              1
# ...       ...          ...        ...           ...            ...
# 74037  221398       206588       1.67             5              4
# 74038  221400       206589       1.33             4              2
# 74039  221401       206590       2.33             3              2
# 74040  221404       206593       2.33             3              2
# 74041  221405       206594       2.67             4              3
# 74042  221407       206596       1.67             4              0
# 74043  221408       206597       3.00             5              3
# 74044  221409       206598       2.67             1              0
# 74045  221411       206599       1.33             4              2
# 74046  221412       206600       2.00             1              0
# 74047  221413       206601       1.67             4              3
# 74048  221415       206602       2.00             8              6
# 74049  221416       206603       1.00             5              2
# 74050  221419       206606       2.33             2              2
# 74051  221420       206607       2.00             4              3
# 74052  221422       206609       2.33             3              2
# 74053  221423       206610       2.33             4              3
# 74054  221426       206613       2.00             4              2
# 74055  221427       206614       1.67             4              3
# 74056  221432       206619       2.00             3              2
# 74057  221434       206621       2.67             3              2
# 74058  221443       206627       3.00             3              3
# 74059  221449       206631       3.00             5              4
# 74060  221450       206632       2.00             2              1
# 74061  221455       206637       3.00             6              4
# 74062  221457       206638       1.00             3              1
# 74063  221458       206639       3.00             3              3
# 74064  221463       206641       2.33             7              2
# 74065  221471       206648       3.00             3              2
# 74066  221473       206650       2.33             5              3
#
#        word_in_description  jackard_similarity
# 0                        1            0.350000
# 1                        1            0.250000
# 2                        1            0.296296
# 3                        1            0.478261
# 4                        2            0.652174
# 5                        2            0.347826
# 6                        2            0.521739
# 7                        1            0.347826
# 8                        2            0.409091
# 9                        2            0.318182
# 10                       2            0.318182
# 11                       5            0.576923
# 12                       2            0.269231
# 13                       1            0.384615
# 14                       3            0.592593
# 15                       1            0.277778
# 16                       2            0.454545
# 17                       1            0.240000
# 18                       0            0.520000
# 19                       0            0.280000
# 20                       2            0.360000
# 21                       2            0.416667
# 22                       1            0.400000
# 23                       1            0.416667
# 24                       1            0.208333
# 25                       3            0.545455
# 26                       2            0.590909
# 27                       1            0.391304
# 28                       1            0.434783
# 29                       2            0.521739
# ...                    ...                 ...
# 74037                    4            0.550000
# 74038                    2            0.541667
# 74039                    1            0.583333
# 74040                    2            0.400000
# 74041                    3            0.481481
# 74042                    1            0.392857
# 74043                    4            0.571429
# 74044                    0            0.500000
# 74045                    3            0.480000
# 74046                    0            0.269231
# 74047                    2            0.550000
# 74048                    5            0.750000
# 74049                    4            0.666667
# 74050                    0            0.500000
# 74051                    2            0.440000
# 74052                    2            0.833333
# 74053                    0            0.590909
# 74054                    3            0.428571
# 74055                    3            0.555556
# 74056                    2            0.520000
# 74057                    2            0.357143
# 74058                    2            0.684211
# 74059                    3            0.625000
# 74060                    1            0.400000
# 74061                    5            0.640000
# 74062                    1            0.370370
# 74063                    2            0.500000
# 74064                    4            0.739130
# 74065                    2            0.428571
# 74066                    2            0.433333
#
# [74067 rows x 7 columns]

# %% [markdown]
# #Training a random forest

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
rf = RandomForestRegressor(n_estimators=15, max_depth=6, random_state=0)
clf = BaggingRegressor(rf, n_estimators=45, max_samples=0.1, random_state=25)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)
# Out:
# CPU times: user 13.8 s, sys: 157 ms, total: 14 s
# Wall time: 15 s

# %% [markdown]
# #Training a extreme gradient boosted tree

# %%
import xgboost as xgb

# %%
from sklearn.cross_validation import train_test_split

# %%
XTrain, XTest, yTrain, yTest = train_test_split(X_train, y_train, test_size=0.25)

# %%
dTrain = xgb.DMatrix(XTrain, label=yTrain)
dTest = xgb.DMatrix(XTest, label=yTest)
param = {'bst:max_depth':6, 'bst:eta':0.1, 'silent':0, 'objective':'reg:linear' }
param['nthread'] = 4
evallist  = [(dTest,'eval'), (dTrain,'train')]

# %%
num_round=200

# %%
bst = xgb.train( param, dTrain, num_round, evallist )
# Out:
# [0]	eval-rmse:1.774484	train-rmse:1.772379
# [1]	eval-rmse:1.610963	train-rmse:1.608918
# [2]	eval-rmse:1.465164	train-rmse:1.463176
# [3]	eval-rmse:1.335447	train-rmse:1.333421
# [4]	eval-rmse:1.220322	train-rmse:1.218213
# [5]	eval-rmse:1.118354	train-rmse:1.116156
# [6]	eval-rmse:1.028357	train-rmse:1.026053
# [7]	eval-rmse:0.949180	train-rmse:0.946753
# [8]	eval-rmse:0.879850	train-rmse:0.877205
# [9]	eval-rmse:0.819323	train-rmse:0.816514
# [10]	eval-rmse:0.766741	train-rmse:0.763651
# [11]	eval-rmse:0.721296	train-rmse:0.717929
# [12]	eval-rmse:0.682246	train-rmse:0.678548
# [13]	eval-rmse:0.648910	train-rmse:0.644912
# [14]	eval-rmse:0.620470	train-rmse:0.616148
# [15]	eval-rmse:0.596412	train-rmse:0.591773
# [16]	eval-rmse:0.576215	train-rmse:0.571299
# [17]	eval-rmse:0.559225	train-rmse:0.554065
# [18]	eval-rmse:0.545086	train-rmse:0.539698
# [19]	eval-rmse:0.533179	train-rmse:0.527540
# [20]	eval-rmse:0.523371	train-rmse:0.517496
# [21]	eval-rmse:0.515209	train-rmse:0.509138
# [22]	eval-rmse:0.508641	train-rmse:0.502293
# [23]	eval-rmse:0.503071	train-rmse:0.496565
# [24]	eval-rmse:0.498570	train-rmse:0.491884
# [25]	eval-rmse:0.494910	train-rmse:0.488003
# [26]	eval-rmse:0.491955	train-rmse:0.484795
# [27]	eval-rmse:0.489509	train-rmse:0.482151
# [28]	eval-rmse:0.487537	train-rmse:0.479967
# [29]	eval-rmse:0.485887	train-rmse:0.478159
# [30]	eval-rmse:0.484518	train-rmse:0.476590
# [31]	eval-rmse:0.483398	train-rmse:0.475320
# [32]	eval-rmse:0.482555	train-rmse:0.474319
# [33]	eval-rmse:0.481878	train-rmse:0.473477
# [34]	eval-rmse:0.481302	train-rmse:0.472703
# [35]	eval-rmse:0.480831	train-rmse:0.472039
# [36]	eval-rmse:0.480455	train-rmse:0.471511
# [37]	eval-rmse:0.480149	train-rmse:0.471087
# [38]	eval-rmse:0.479844	train-rmse:0.470679
# [39]	eval-rmse:0.479632	train-rmse:0.470305
# [40]	eval-rmse:0.479477	train-rmse:0.469941
# [41]	eval-rmse:0.479351	train-rmse:0.469692
# [42]	eval-rmse:0.479202	train-rmse:0.469412
# [43]	eval-rmse:0.479152	train-rmse:0.469237
# [44]	eval-rmse:0.479068	train-rmse:0.469039
# [45]	eval-rmse:0.479000	train-rmse:0.468823
# [46]	eval-rmse:0.478954	train-rmse:0.468617
# [47]	eval-rmse:0.478905	train-rmse:0.468548
# [48]	eval-rmse:0.478872	train-rmse:0.468453
# [49]	eval-rmse:0.478831	train-rmse:0.468302
# [50]	eval-rmse:0.478813	train-rmse:0.468258
# [51]	eval-rmse:0.478800	train-rmse:0.468117
# [52]	eval-rmse:0.478762	train-rmse:0.467932
# [53]	eval-rmse:0.478747	train-rmse:0.467868
# [54]	eval-rmse:0.478717	train-rmse:0.467819
# [55]	eval-rmse:0.478700	train-rmse:0.467711
# [56]	eval-rmse:0.478691	train-rmse:0.467680
# [57]	eval-rmse:0.478710	train-rmse:0.467521
# [58]	eval-rmse:0.478712	train-rmse:0.467476
# [59]	eval-rmse:0.478681	train-rmse:0.467321
# [60]	eval-rmse:0.478658	train-rmse:0.467272
# [61]	eval-rmse:0.478643	train-rmse:0.467102
# [62]	eval-rmse:0.478611	train-rmse:0.466934
# [63]	eval-rmse:0.478611	train-rmse:0.466901
# [64]	eval-rmse:0.478619	train-rmse:0.466859
# [65]	eval-rmse:0.478621	train-rmse:0.466841
# [66]	eval-rmse:0.478589	train-rmse:0.466674
# [67]	eval-rmse:0.478590	train-rmse:0.466555
# [68]	eval-rmse:0.478602	train-rmse:0.466537
# [69]	eval-rmse:0.478596	train-rmse:0.466467
# [70]	eval-rmse:0.478606	train-rmse:0.466335
# [71]	eval-rmse:0.478613	train-rmse:0.466245
# [72]	eval-rmse:0.478621	train-rmse:0.466225
# [73]	eval-rmse:0.478618	train-rmse:0.466193
# [74]	eval-rmse:0.478632	train-rmse:0.466171
# [75]	eval-rmse:0.478600	train-rmse:0.466044
# [76]	eval-rmse:0.478608	train-rmse:0.465921
# [77]	eval-rmse:0.478620	train-rmse:0.465838
# [78]	eval-rmse:0.478602	train-rmse:0.465794
# [79]	eval-rmse:0.478625	train-rmse:0.465647
# [80]	eval-rmse:0.478639	train-rmse:0.465526
# [81]	eval-rmse:0.478647	train-rmse:0.465501
# [82]	eval-rmse:0.478679	train-rmse:0.465402
# [83]	eval-rmse:0.478693	train-rmse:0.465367
# [84]	eval-rmse:0.478681	train-rmse:0.465277
# [85]	eval-rmse:0.478704	train-rmse:0.465173
# [86]	eval-rmse:0.478705	train-rmse:0.465151
# [87]	eval-rmse:0.478720	train-rmse:0.465132
# [88]	eval-rmse:0.478721	train-rmse:0.465068
# [89]	eval-rmse:0.478720	train-rmse:0.464952
# [90]	eval-rmse:0.478739	train-rmse:0.464803
# [91]	eval-rmse:0.478714	train-rmse:0.464670
# [92]	eval-rmse:0.478727	train-rmse:0.464526
# [93]	eval-rmse:0.478737	train-rmse:0.464499
# [94]	eval-rmse:0.478737	train-rmse:0.464483
# [95]	eval-rmse:0.478748	train-rmse:0.464471
# [96]	eval-rmse:0.478748	train-rmse:0.464307
# [97]	eval-rmse:0.478765	train-rmse:0.464256
# [98]	eval-rmse:0.478772	train-rmse:0.464238
# [99]	eval-rmse:0.478779	train-rmse:0.464169
# [100]	eval-rmse:0.478770	train-rmse:0.464049
# [101]	eval-rmse:0.478768	train-rmse:0.463954
# [102]	eval-rmse:0.478772	train-rmse:0.463931
# [103]	eval-rmse:0.478772	train-rmse:0.463917
# [104]	eval-rmse:0.478792	train-rmse:0.463831
# [105]	eval-rmse:0.478793	train-rmse:0.463808
# [106]	eval-rmse:0.478799	train-rmse:0.463792
# [107]	eval-rmse:0.478801	train-rmse:0.463705
# [108]	eval-rmse:0.478811	train-rmse:0.463588
# [109]	eval-rmse:0.478819	train-rmse:0.463573
# [110]	eval-rmse:0.478858	train-rmse:0.463460
# [111]	eval-rmse:0.478857	train-rmse:0.463308
# [112]	eval-rmse:0.478868	train-rmse:0.463295
# [113]	eval-rmse:0.478872	train-rmse:0.463277
# [114]	eval-rmse:0.478887	train-rmse:0.463258
# [115]	eval-rmse:0.478889	train-rmse:0.463135
# [116]	eval-rmse:0.478880	train-rmse:0.462991
# [117]	eval-rmse:0.478875	train-rmse:0.462897
# [118]	eval-rmse:0.478887	train-rmse:0.462742
# [119]	eval-rmse:0.478901	train-rmse:0.462576
# [120]	eval-rmse:0.478917	train-rmse:0.462497
# [121]	eval-rmse:0.478940	train-rmse:0.462344
# [122]	eval-rmse:0.478940	train-rmse:0.462251
# [123]	eval-rmse:0.478946	train-rmse:0.462238
# [124]	eval-rmse:0.478958	train-rmse:0.462189
# [125]	eval-rmse:0.478956	train-rmse:0.462081
# [126]	eval-rmse:0.478958	train-rmse:0.462063
# [127]	eval-rmse:0.478971	train-rmse:0.462055
# [128]	eval-rmse:0.478985	train-rmse:0.461894
# [129]	eval-rmse:0.478980	train-rmse:0.461801
# [130]	eval-rmse:0.478954	train-rmse:0.461666
# [131]	eval-rmse:0.478958	train-rmse:0.461582
# [132]	eval-rmse:0.478960	train-rmse:0.461560
# [133]	eval-rmse:0.478971	train-rmse:0.461549
# [134]	eval-rmse:0.478969	train-rmse:0.461487
# [135]	eval-rmse:0.478990	train-rmse:0.461372
# [136]	eval-rmse:0.478981	train-rmse:0.461306
# [137]	eval-rmse:0.478988	train-rmse:0.461260
# [138]	eval-rmse:0.479008	train-rmse:0.461226
# [139]	eval-rmse:0.478992	train-rmse:0.461099
# [140]	eval-rmse:0.478976	train-rmse:0.460980
# [141]	eval-rmse:0.478984	train-rmse:0.460955
# [142]	eval-rmse:0.478990	train-rmse:0.460944
# [143]	eval-rmse:0.479026	train-rmse:0.460837
# [144]	eval-rmse:0.479042	train-rmse:0.460759
# [145]	eval-rmse:0.479006	train-rmse:0.460645
# [146]	eval-rmse:0.479014	train-rmse:0.460471
# [147]	eval-rmse:0.479022	train-rmse:0.460402
# [148]	eval-rmse:0.479026	train-rmse:0.460300
# [149]	eval-rmse:0.479044	train-rmse:0.460274
# [150]	eval-rmse:0.479057	train-rmse:0.460221
# [151]	eval-rmse:0.479075	train-rmse:0.460122
# [152]	eval-rmse:0.479098	train-rmse:0.460005
# [153]	eval-rmse:0.479109	train-rmse:0.459995
# [154]	eval-rmse:0.479108	train-rmse:0.459981
# [155]	eval-rmse:0.479112	train-rmse:0.459939
# [156]	eval-rmse:0.479103	train-rmse:0.459909
# [157]	eval-rmse:0.479102	train-rmse:0.459899
# [158]	eval-rmse:0.479110	train-rmse:0.459890
# [159]	eval-rmse:0.479142	train-rmse:0.459817
# [160]	eval-rmse:0.479140	train-rmse:0.459735
# [161]	eval-rmse:0.479149	train-rmse:0.459701
# [162]	eval-rmse:0.479174	train-rmse:0.459623
# [163]	eval-rmse:0.479185	train-rmse:0.459549
# [164]	eval-rmse:0.479194	train-rmse:0.459516
# [165]	eval-rmse:0.479209	train-rmse:0.459450
# [166]	eval-rmse:0.479212	train-rmse:0.459338
# [167]	eval-rmse:0.479235	train-rmse:0.459205
# [168]	eval-rmse:0.479236	train-rmse:0.459075
# [169]	eval-rmse:0.479248	train-rmse:0.458977
# [170]	eval-rmse:0.479235	train-rmse:0.458894
# [171]	eval-rmse:0.479239	train-rmse:0.458834
# [172]	eval-rmse:0.479258	train-rmse:0.458686
# [173]	eval-rmse:0.479244	train-rmse:0.458502
# [174]	eval-rmse:0.479239	train-rmse:0.458433
# [175]	eval-rmse:0.479256	train-rmse:0.458332
# [176]	eval-rmse:0.479275	train-rmse:0.458243
# [177]	eval-rmse:0.479261	train-rmse:0.458120
# [178]	eval-rmse:0.479268	train-rmse:0.458112
# [179]	eval-rmse:0.479273	train-rmse:0.458062
# [180]	eval-rmse:0.479279	train-rmse:0.457924
# [181]	eval-rmse:0.479289	train-rmse:0.457825
# [182]	eval-rmse:0.479289	train-rmse:0.457708
# [183]	eval-rmse:0.479294	train-rmse:0.457588
# [184]	eval-rmse:0.479307	train-rmse:0.457452
# [185]	eval-rmse:0.479308	train-rmse:0.457437
# [186]	eval-rmse:0.479315	train-rmse:0.457430
# [187]	eval-rmse:0.479313	train-rmse:0.457418
# [188]	eval-rmse:0.479316	train-rmse:0.457301
# [189]	eval-rmse:0.479319	train-rmse:0.457208
# [190]	eval-rmse:0.479322	train-rmse:0.457192
# [191]	eval-rmse:0.479342	train-rmse:0.457155
# [192]	eval-rmse:0.479378	train-rmse:0.456965
# [193]	eval-rmse:0.479424	train-rmse:0.456835
# [194]	eval-rmse:0.479443	train-rmse:0.456721
# [195]	eval-rmse:0.479447	train-rmse:0.456646
# [196]	eval-rmse:0.479468	train-rmse:0.456538
# [197]	eval-rmse:0.479494	train-rmse:0.456447
# [198]	eval-rmse:0.479496	train-rmse:0.456419
# [199]	eval-rmse:0.479514	train-rmse:0.456404

# %%
pred = bst.predict(xgb.DMatrix(X_test))
pred[pred>3] = 3
pred[pred<1] = 1

# %%
pd.DataFrame({"id": id_test, "relevance": pred}).to_csv('submission_xgb_02_29_2016.csv',index=False)

# %%
avg_pred = (y_pred+pred)/2

# %%
pd.DataFrame({"id": id_test, "relevance": pred}).to_csv('submission_xgb_rfr_averaged.csv',index=False)
